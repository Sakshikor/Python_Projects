# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Hp\Downloads/50_Startups.csv")

# %%
df.isnull().sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
x=df.drop(labels=['STATE'],axis=1)
y=df[['STATE']]

# %%
from sklearn.preprocessing import LabelEncoder ,StandardScaler

# %%
le=LabelEncoder()
ss=StandardScaler()

# %%
Y=pd.DataFrame(le.fit_transform(y))
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
Y.value_counts()
# Out:
# 0    17
# 2    17
# 1    16
# dtype: int64

# %%
X=pd.DataFrame(ss.fit_transform(x),columns=x.columns)

# %%
X
# Out:
#          RND     ADMIN       MKT    PROFIT
# 0   2.016411  0.560753  2.153943  2.011203
# 1   1.955860  1.082807  1.923600  1.999430
# 2   1.754364 -0.728257  1.626528  1.980842
# 3   1.554784 -0.096365  1.422210  1.776627
# 4   1.504937 -1.079919  1.281528  1.357740
# 5   1.279800 -0.776239  1.254210  1.127250
# 6   1.340066  0.932147 -0.688150  1.105481
# 7   1.245057  0.871980  0.932186  1.096210
# 8   1.030369  0.986952  0.830887  1.007470
# 9   1.091819 -0.456640  0.776107  0.946022
# 10  0.620398 -0.387599  0.149807  0.854847
# 11  0.593085 -1.065540  0.319834  0.808168
# 12  0.443260  0.215449  0.320617  0.741155
# 13  0.402078  0.510179  0.343957  0.558750
# 14  1.017181  1.269199  0.375742  0.516026
# 15  0.897913  0.045868  0.419219  0.448720
# 16  0.094441  0.009118  0.440446  0.375436
# 17  0.460720  0.855666  0.591017  0.334771
# 18  0.396725 -0.258465  0.692992  0.307116
# 19  0.279442  1.159837 -1.743127  0.269773
# 20  0.055726 -0.269588  0.723926  0.161935
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
model=lr.fit(xtrain,ytrain)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
tr_pred=model.predict(xtrain)
ts_pred=model.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
tr_score=accuracy_score(ytrain,tr_pred)
ts_score=accuracy_score(ytest,ts_pred)

# %%
print(tr_pred)
print(ts_pred)
print(tr_score)
print(ts_score)
# Out:
# [1 2 2 1 0 1 1 0 1 2 1 1 2 1 1 1 2 1 1 1 0 1 1 2 1 1 2 1 1 2 1 1 2 2 0 2 1
#  2 2 0]
# [2 2 2 2 2 0 0 0 1 1]
# 0.4
# 0.3

# %%
met=confusion_matrix(ytrain,tr_pred)
met
# Out:
# array([[ 0,  6,  5],
#        [ 3, 10,  2],
#        [ 2,  6,  6]], dtype=int64)

# %%
model.predict_proba(xtrain) # this will show probabilities
# Out:
# array([[0.21728245, 0.51829421, 0.26442333],
#        [0.34802217, 0.29842381, 0.35355403],
#        [0.17528614, 0.39564503, 0.42906883],
#        [0.34115811, 0.39207232, 0.26676957],
#        [0.36398049, 0.27759279, 0.35842672],
#        [0.23482556, 0.46136496, 0.30380947],
#        [0.22672773, 0.39667937, 0.3765929 ],
#        [0.40277927, 0.25101554, 0.34620519],
#        [0.28910418, 0.40968649, 0.30120933],
#        [0.361093  , 0.21684726, 0.42205974],
#        [0.29768579, 0.41043192, 0.29188229],
#        [0.20373075, 0.47222938, 0.32403987],
#        [0.24020217, 0.35400009, 0.40579774],
#        [0.29078915, 0.38679378, 0.32241707],
#        [0.27619926, 0.38523647, 0.33856427],
#        [0.27549516, 0.41567264, 0.3088322 ],
#        [0.26042143, 0.2814841 , 0.45809446],
#        [0.1912623 , 0.44770996, 0.36102774],
#        [0.1808243 , 0.48070743, 0.33846827],
#        [0.20902248, 0.5369877 , 0.25398981],
#        [0.46474197, 0.26248044, 0.27277759],
# ...
